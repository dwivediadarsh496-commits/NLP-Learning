# %% [markdown]
# Data preprosscing

# %%
import numpy as np
import pandas as pd



df = pd.read_csv("customer_segmentation_data.csv")


print("Missing Values:")
print(df.isnull().sum())


print("\nMissing Values Percentage:")
print((df.isnull().sum() / len(df)) * 100)

numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()

print("\nNumerical Features:")
print(numerical_features)

print("\nCategorical Features:")
print(categorical_features)
# Out:
# Missing Values:
# id                      0
# age                     0
# gender                  0
# income                  0
# spending_score          0
# membership_years        0
# purchase_frequency      0
# preferred_category      0
# last_purchase_amount    0
# dtype: int64
#
# Missing Values Percentage:
# id                      0.0
# age                     0.0
# gender                  0.0
# income                  0.0
# spending_score          0.0
# membership_years        0.0
# purchase_frequency      0.0
# preferred_category      0.0
# last_purchase_amount    0.0
# dtype: float64
#
# Numerical Features:
# ['id', 'age', 'income', 'spending_score', 'membership_years', 'purchase_frequency', 'last_purchase_amount']
#
# Categorical Features:
# ['gender', 'preferred_category']

# %% [markdown]
# one hot encoding

# %%
df_encoded = pd.get_dummies(df, columns=categorical_features, drop_first=True)
print(df_encoded.head())
# Out:
#    id  age  income  spending_score  membership_years  purchase_frequency  \
# 0   1   38   99342              90                 3                  24
# 1   2   21   78852              60                 2                  42
# 2   3   60  126573              30                 2                  28
# 3   4   40   47099              74                 9                   5
# 4   5   65  140621              21                 3                  25
#
#    last_purchase_amount  gender_Male  gender_Other  \
# 0                113.53        False         False
# 1                 41.93        False         False
# 2                424.36        False         False
# 3                991.93        False          True
# 4                347.08        False         False
#
#    preferred_category_Electronics  preferred_category_Groceries  \
# 0                           False                          True
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                            True                         False
#
#    preferred_category_Home & Garden  preferred_category_Sports
# 0                             False                      False
# 1                             False                       True
# 2                             False                      False
# 3                              True                      False
# 4                             False                      False

# %%
print("\nMinimum Values:")
print(df[numerical_features].min())
# Out:
# Minimum Values:
# id                          1.0
# age                        18.0
# income                  30004.0
# spending_score              1.0
# membership_years            1.0
# purchase_frequency          1.0
# last_purchase_amount       10.4
# dtype: float64

# %%
print("\nMaximum Values:")
print(df[numerical_features].max())
# Out:
# Maximum Values:
# id                        1000.00
# age                         69.00
# income                  149973.00
# spending_score             100.00
# membership_years            10.00
# purchase_frequency          50.00
# last_purchase_amount       999.74
# dtype: float64

# %%
print("\nStandard Deviation:")
print(df[numerical_features].std())
# Out:
# Standard Deviation:
# id                        288.819436
# age                        15.042213
# income                  34230.771122
# spending_score             28.955175
# membership_years            2.855730
# purchase_frequency         14.243654
# last_purchase_amount      295.744253
# dtype: float64
